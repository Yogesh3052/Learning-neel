# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20, 'figure.figsize': (10, 8)})
data = [['tom', 10, 50], ['nick', 15, 67], ['juli', 14, 87]]

df = pd.DataFrame(data, columns=['Name', 'Age', 'Score'])

# %%
df
# Out:
#    Name  Age  Score
# 0   tom   10     50
# 1  nick   15     67
# 2  juli   14     87

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.plot(kind='scatter', x='Age', y='Score', title='age vs score chart')
# Out:
# <AxesSubplot: title={'center': 'age vs score chart'}, xlabel='Age', ylabel='Score'>

# %%
df.plot(kind='hist', x='Age', y='Score', title='age vs score chart')
# Out:
# <AxesSubplot: title={'center': 'age vs score chart'}, ylabel='Frequency'>

# %%
df.plot (kind= 'pie', x='Age', y='Score', title=' age vs score chart')
# Out:
# <AxesSubplot: title={'center': ' age vs score chart'}, ylabel='Score'>

# %%
df.plot (kind="hist', x='age', y="Score', title=' age vs score chart')
# Out:
#   Input In [9]
#     df.plot (kind="hist', x='age', y="Score', title=' age vs score chart')
#                                       ^
# SyntaxError: invalid syntax

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
X = np.arange(-5, 5, 0.15)
Y = np.arange(-5, 5, 0.15)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# %%
import numpy as np

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
X = np.arange(-5, 5, 0.15)
Y = np.arange(-5, 5, 0.15)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='viridis')
